# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv("co2-annmean-gl.csv")
df1
# Out:
#     Year    Mean  Uncertainty
# 0   1979  336.85         0.11
# 1   1980  338.91         0.07
# 2   1981  340.11         0.09
# 3   1982  340.86         0.03
# 4   1983  342.53         0.06
# 5   1984  344.07         0.08
# 6   1985  345.54         0.07
# 7   1986  346.97         0.07
# 8   1987  348.68         0.10
# 9   1988  351.16         0.07
# 10  1989  352.79         0.07
# 11  1990  354.06         0.07
# 12  1991  355.39         0.07
# 13  1992  356.09         0.06
# 14  1993  356.83         0.07
# 15  1994  358.33         0.08
# 16  1995  360.17         0.05
# 17  1996  361.93         0.04
# 18  1997  363.04         0.05
# 19  1998  365.70         0.04
# 20  1999  367.79         0.05
# 21  2000  368.96         0.06
# 22  2001  370.57         0.05
# 23  2002  372.58         0.04
# 24  2003  375.14         0.04
# 25  2004  376.95         0.06
# 26  2005  378.98         0.05
# 27  2006  381.15         0.05
# 28  2007  382.90         0.04
# 29  2008  385.02         0.05
# ...

# %% [markdown]
# # The resulting plot will show a histogram of the mean CO2 levels, with the x-axis representing the CO2 levels in parts per million (ppm) and the y-axis representing the frequency of occurrence. Additionally, there will be a smoothed curve overlaying the histogram, representing the kernel density estimate of the distribution. The bars of the histogram will be colored red, and gridlines will be present to aid visualization.

# %%
plt.figure(figsize=(4,4))
sns.histplot(df1['Mean'], bins=30, kde=True, color='red')
plt.title('Distribution of Mean CO2 Levels')
plt.xlabel('Mean CO2 Level (ppm)')
plt.ylabel('Uncertainty')
plt.grid(True)
plt.show()

# %% [markdown]
# # The resulting plot will show a comperison line chart  between the mean CO2 levels and co2-annmean-mlo csv, in the plot it is compared the year waise co2 lavel of 2 data set

# %%
plt.figure(figsize=(4,4))
plt.plot(df1['Year'], df1['Mean'], color='b')
plt.plot(df2['Year'], df2['Mean'], color='r')
plt.title('Mean CO2 Levels Over Years')
plt.xlabel('Year')
plt.ylabel('Mean CO2 Level (ppm)')
plt.show()

# %% [markdown]
# # The resulting scatter plot will show the relationship between mean CO2 levels and years, with markers from df1 plotted in blue and markers from df2 plotted in red. The x-axis represents mean CO2 levels in parts per million (ppm), and the y-axis represents the years. The title "Co2 Level VS Uncertainty" indicates the content of the plot, and labels on the axes provide additional context.

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(df1,x="Mean",y="Year", color='b')
sns.scatterplot(df2,x="Mean",y="Year", color='r')
plt.title('Co2 lavel VS Uncertainty')
plt.xlabel('Mean CO2 Level (ppm)')
plt.ylabel('Year')
plt.show()

# %% [markdown]
# # The resulting bar plot will show the mean CO2 levels over the years for the first 10 entries in the DataFrame df1, with each bar representing a specific year. The x-axis represents the years, and the y-axis represents the mean CO2 levels in parts per million (ppm). The title "Co2 increase in Year Frequency" indicates the content of the plot, and labels on the axes provide additional context.New Section

# %%
d=df1.head(10)
plt.figure(figsize=(6,6))
plt.bar(d["Year"],d["Mean"],color=('red','yellow','green','skyblue','pink'),edgecolor="b")
plt.title("Co2 increse in Year Frequency")
plt.xlabel("Year")
plt.ylabel("Mean")
plt.show()

# %%
df2=pd.read_csv("co2-annmean-mlo.csv")
df2
# Out:
#     Year    Mean  Uncertainty
# 0   1959  315.98         0.12
# 1   1960  316.91         0.12
# 2   1961  317.64         0.12
# 3   1962  318.45         0.12
# 4   1963  318.99         0.12
# ..   ...     ...          ...
# 60  2019  411.65         0.12
# 61  2020  414.21         0.12
# 62  2021  416.41         0.12
# 63  2022  418.53         0.12
# 64  2023  421.08         0.12
#
# [65 rows x 3 columns]

# %%
plt.figure(figsize=(4,4))
sns.histplot(df2['Mean'], bins=30, kde=True, color='r',edgecolor='b')
plt.title('Distribution of Mean CO2 Levels')
plt.xlabel('Mean CO2 Level (ppm)')
plt.ylabel('Uncertainty')
plt.grid(True)
plt.show()

# %%
df3=pd.read_csv("co2-gr-gl.csv")
df3
# Out:
#     Year  Annual Increase  Uncertainty
# 0   1959             0.96         0.31
# 1   1960             0.71         0.27
# 2   1961             0.78         0.27
# 3   1962             0.56         0.27
# 4   1963             0.57         0.28
# ..   ...              ...          ...
# 59  2018             2.39         0.09
# 60  2019             2.52         0.06
# 61  2020             2.36         0.08
# 62  2021             2.46         0.08
# 63  2022             2.16         0.08
#
# [64 rows x 3 columns]

# %%
plt.figure(figsize=(4,4))
plt.plot(df3['Year'], df3['Annual Increase'],marker='*',markerfacecolor='black', color='violet')
plt.title('Mean CO2 Levels Over Years')
plt.xlabel('Year')
plt.ylabel('Mean CO2 Level (ppm)')
plt.show()

# %%
df4=pd.read_csv("co2-gr-mlo.csv")
df4
# Out:
#     Year  Annual Increase  Uncertainty
# 0   1959             0.94         0.11
# 1   1960             0.50         0.11
# 2   1961             0.96         0.11
# 3   1962             0.64         0.11
# 4   1963             0.71         0.11
# ..   ...              ...          ...
# 59  2018             2.85         0.11
# 60  2019             2.49         0.11
# 61  2020             2.32         0.11
# 62  2021             2.36         0.11
# 63  2022             1.81         0.11
#
# [64 rows x 3 columns]

# %%
plt.figure(figsize=(4,4))
plt.plot(df4['Year'], df4['Annual Increase'],marker='*',markerfacecolor='black', color='skyblue')
plt.title('Mean CO2 Levels Over Years')
plt.xlabel('Year')
plt.ylabel('Mean CO2 Level (ppm)')
plt.show()

# %% [markdown]
# #The resulting plot will show the trend of annual increase in mean CO2 levels over the years for both DataFrames, with stars marking individual data points. The x-axis represents the years, and the y-axis represents the annual increase in mean CO2 levels in parts per million (ppm). The title "Mean CO2 Levels Over Years" indicates the content of the plot, and labels on the axes provide additional conte Section

# %%
plt.figure(figsize=(4,4))
plt.plot(df4['Year'], df4['Annual Increase'],marker='*',markerfacecolor='black', color='skyblue')
plt.plot(df3['Year'], df3['Annual Increase'],marker='*',markerfacecolor='black', color='gray')
plt.title('Mean CO2 Levels Over Years')
plt.xlabel('Year')
plt.ylabel('Mean CO2 Level (ppm)')
plt.show()

# %% [markdown]
# # The resulting scatter plot will show the relationship between the annual increase in CO2 levels and years for both DataFrames. Each marker represents a specific year, with its position determined by the annual increase in CO2 levels. The x-axis represents the annual increase in CO2 levels, and the y-axis represents the years. The title "Annual increase of CO2 per year" indicates the content of the plot, and labels on the axes provide additional context.

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(df3,x="Annual Increase",y="Year", color='b')
sns.scatterplot(df4,x="Annual Increase",y="Year", color='gray')
plt.title('Annual increase of co2 per year ')
plt.xlabel('Annual Increase')
plt.ylabel('Year')
plt.show()

# %%
df5=pd.read_csv("co2-mm-gl.csv")
df5
# Out:
#                     Date  Decimal Date  Average  Trend
# 1979-01 1979.042  336.56          0.11   335.92   0.09
# 1979-02 1979.125  337.29          0.09   336.25   0.10
# 1979-03 1979.208  337.88          0.11   336.51   0.10
# 1979-04 1979.292  338.32          0.12   336.72   0.10
# 1979-05 1979.375  338.26          0.03   336.71   0.10
# ...                  ...           ...      ...    ...
# 2023-07 2023.542  417.86          0.10   419.15   0.06
# 2023-08 2023.625  416.60          0.10   419.44   0.06
# 2023-09 2023.708  416.98          0.10   419.78   0.06
# 2023-10 2023.792  418.64          0.10   420.13   0.06
# 2023-11 2023.875  420.15          0.10   420.38   0.06
#
# [539 rows x 4 columns]

# %% [markdown]
# # **This pair plot allows you to visualize the relationship between the 'Average' and 'Trend' variables, as well as the distribution of each variable individually. It's particularly useful when you want to explore correlations and distributions between multiple variables in your dataset.**

# %%
plt.figure(figsize=(6,6))
sns.pairplot(df5)
plt.title("Pair Plot of Average and Trend")
# Out:
# Text(0.5, 1.0, 'Pair Plot of Average and Trend')

# %%
df6=pd.read_csv("co2-mm-mlo.csv")
df6
# Out:
#               Date  Decimal Date  Average  Interpolated  Trend  Number of Days
# 1958-03  1958.2027        315.70   314.43            -1  -9.99           -0.99
# 1958-04  1958.2877        317.45   315.16            -1  -9.99           -0.99
# 1958-05  1958.3699        317.51   314.71            -1  -9.99           -0.99
# 1958-06  1958.4548        317.24   315.14            -1  -9.99           -0.99
# 1958-07  1958.5370        315.86   315.18            -1  -9.99           -0.99
# ...            ...           ...      ...           ...    ...             ...
# 2023-09  2023.7083        418.51   421.96            18   0.30            0.14
# 2023-10  2023.7917        418.82   422.12            27   0.47            0.17
# 2023-11  2023.8750        420.46   422.43            21   0.91            0.38
# 2023-12  2023.9583        421.86   422.56            20   0.70            0.30
# 2024-01  2024.0417        422.80   422.53            27   0.60            0.22
#
# [791 rows x 6 columns]

# %% [markdown]
# # This plot shows the trend of monthly mean CO2 levels at the Mauna Loa Observatory over time. The x-axis represents the dates, and the y-axis represents the CO2 levels in parts per million (ppm). The blue line represents the interpolated CO2 levels.

# %%
plt.figure(figsize=(10,6))
plt.plot(df6['Date'], df6['Interpolated'], color='blue', label='CO2 Levels')
plt.xlabel('Date')
plt.ylabel('CO2 Levels (ppm)')
plt.title('Monthly Mean CO2 Levels at Mauna Loa Observatory')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Out:
#      Year  Mean_MLO  Uncertainty_Mean_MLO  Annual_Increase_MLO  \
# 0   False     False                 False                False
# 1   False     False                 False                False
# 2   False     False                 False                False
# 3   False     False                 False                False
# 4   False     False                 False                False
# ..    ...       ...                   ...                  ...
# 59  False     False                 False                False
# 60  False     False                 False                False
# 61  False     False                 False                False
# 62  False     False                 False                False
# 63  False     False                 False                False
#
#     Uncertainty_Inc_MLO  Mean_GL  Uncertainty_Mean_GL  Annual_Increase_GL  \
# 0                 False     True                 True                True
# ...
